# %% [markdown]
# # Collect data from Wikipedia

# %% [markdown]
# The dataset collected by this script via WikiTopicsCollector consists of Wikipedia pageviews and metadata for various topics related to artificial intelligence, machine learning, and related fields.
#
# The data is gathered through the Wikimedia API, which provides access to page metadata, links to related topics, and daily pageview statistics over the past ten years.
#
# The collection process starts with a predefined list of seed topics, which are expanded recursively by following Wikipedia’s internal links. The seed topics include two main categories:
#
#
#
# *   **AI & Data Science Domains:** Examples include Artificial Intelligence, Machine Learning, Deep Learning, Computer Vision, Natural Language Processing, Reinforcement Learning, and Data Science.
# *   **AI Models & Techniques:** Examples include ResNet, YOLO, BERT, GPT-3, AlphaGo, PPO, GANs, Stable Diffusion, Wav2Vec, and Graph Neural Networks.
#
# For each topic, metadata is collected, and daily pageviews are retrieved. The collected metadata includes:
#
#
# * article: The Wikipedia page title.
# * date: The date of recorded pageviews in YYYYMMDD format.
# * views: The number of pageviews for that day.
# * weekday: The day of the week corresponding to the date.
# * page_id: A unique identifier for the Wikipedia page.
# * creation_date: The date when the Wikipedia page was first created.
# * last_modified: The last time the page was updated.
# * page_url: The direct link to the Wikipedia page.
# * description: A short text snippet extracted from the page’s introduction.
# * category: The first Wikipedia category assigned to the page.
# * subcategory: The second Wikipedia category (if available).
#
# The data collection process ensures that each topic’s evolution and popularity trends can be analyzed over time.

# %%
# Mount Google Drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import requests
import pandas as pd
from datetime import datetime, timedelta
import os
import time
from collections import defaultdict

class WikiTopicsCollector:
    def __init__(self, drive_path=None):
        print("Initializing WikiTopicsCollector...")
        self.base_url = "https://wikimedia.org/api/rest_v1/metrics/pageviews"
        self.wiki_api_url = "https://en.wikipedia.org/w/api.php"
        self.headers = {
            'User-Agent': 'TopicsCollector/1.0 (your@email.com)'
        }

        # Mount Google Drive and set up save path
        try:
            from google.colab import drive
            drive.mount('/content/drive')
            print("Successfully mounted Google Drive")
        except Exception as e:
            print(f"Error mounting drive: {e}")

        self.save_path = drive_path or "/content/drive/MyDrive/AITrendAnalysis-project/"
        self.filename = "wikipedia_data_with_categories.csv"  # Updated filename
        self.filepath = os.path.join(self.save_path, self.filename)
        print(f"Will save data to: {self.filepath}")

        os.makedirs(self.save_path, exist_ok=True)
        print("Save directory confirmed/created")

    def discover_related_topics(self, seed_topics, max_depth=3):
        print(f"\nStarting topic discovery with {len(seed_topics)} seed topics...")
        all_topics = set(seed_topics)
        topic_metadata = defaultdict(dict)
        topics_to_process = set(seed_topics)
        processed_topics = set()
        data_buffer = []

        for depth in range(max_depth):
            print(f"\nExploring depth {depth + 1}/{max_depth}")
            new_topics = set()

            for topic in topics_to_process:
                if topic in processed_topics:
                    continue

                print(f"Processing topic: {topic}")

                try:
                    params = {
                        "action": "query",
                        "format": "json",
                        "prop": "links|categories|info|extracts",
                        "titles": topic.replace("_", " "),
                        "pllimit": "500",
                        "cllimit": "500",
                        "inprop": "url|created",
                        "exintro": True,
                        "explaintext": True
                    }

                    response = requests.get(self.wiki_api_url, params=params)
                    data = response.json()
                    page = next(iter(data['query']['pages'].values()))

                    if 'pageid' in page:
                        metadata = {
                            'page_id': page['pageid'],
                            'creation_date': page.get('created'),
                            'last_modified': page.get('touched'),
                            'page_url': page.get('fullurl'),
                            'description': page.get('extract', '')[:500],
                            'categories': [cat['title'] for cat in page.get('categories', [])]  # Extract categories
                        }

                        pageview_data = self._get_pageviews(topic, metadata)
                        if pageview_data:
                            data_buffer.extend(pageview_data)

                            if len(data_buffer) >= 100:  # Save every 100 records
                                self._save_to_csv(data_buffer)
                                print(f"Saved batch of {len(data_buffer)} records")
                                data_buffer = []

                        # Collect related topics
                        if 'links' in page:
                            new_topics.update(link['title'] for link in page['links'])

                    processed_topics.add(topic)
                    time.sleep(1)

                except Exception as e:
                    print(f"Error processing {topic}: {e}")
                    continue

            all_topics.update(topics_to_process)
            topics_to_process = new_topics - processed_topics
            print(f"Depth {depth + 1} complete. Found {len(new_topics)} new topics")

            if data_buffer:
                self._save_to_csv(data_buffer)
                print(f"Saved remaining {len(data_buffer)} records")
                data_buffer = []

            if len(all_topics) > 1000:
                print("Reached maximum topic limit")
                break

        return list(all_topics), topic_metadata

    def _get_pageviews(self, article, metadata):
        """Get pageviews for a single article"""
        try:
            start_date, end_date = self._get_date_range(3650)
            url = f"{self.base_url}/per-article/en.wikipedia.org/all-access/user/{article}/daily/{start_date}/{end_date}"

            response = requests.get(url, headers=self.headers)
            data = response.json()

            if 'items' not in data:
                return []

            return [{
                'article': article,
                'date': item['timestamp'],
                'views': item['views'],
                'weekday': datetime.strptime(item['timestamp'], '%Y%m%d00').strftime('%A'),
                'page_id': metadata.get('page_id', ''),
                'creation_date': metadata.get('creation_date', ''),
                'last_modified': metadata.get('last_modified', ''),
                'page_url': metadata.get('page_url', ''),
                'description': metadata.get('description', ''),
                'category': metadata.get('categories', [])[0] if metadata.get('categories') else '',  # Add category
                'subcategory': metadata.get('categories', [])[1] if len(metadata.get('categories', [])) > 1 else ''  # Add subcategory
            } for item in data['items']]

        except Exception as e:
            print(f"Error getting pageviews for {article}: {e}")
            return []

    def _get_date_range(self, days_back):
        """Calculate start and end dates"""
        end_date = datetime.now()
        start_date = end_date - timedelta(days=days_back)
        return start_date.strftime('%Y%m%d'), end_date.strftime('%Y%m%d')

    def _save_to_csv(self, data):
        """Save data to single CSV file"""
        if not data:
            return

        df = pd.DataFrame(data)
        try:
            if os.path.exists(self.filepath):
                df.to_csv(self.filepath, mode='a', header=False, index=False)
            else:
                df.to_csv(self.filepath, index=False)
            print(f"Successfully saved {len(data)} rows to {self.filepath}")
        except Exception as e:
            print(f"Error saving to CSV: {e}")
            fallback_path = os.path.join(os.getcwd(), self.filename)
            print(f"Attempting to save to fallback location: {fallback_path}")
            df.to_csv(fallback_path, index=False)

def main():
    collector = WikiTopicsCollector("/content/drive/MyDrive/AITrendAnalysis-project/")
    ds_domains = [
        'Artificial_intelligence', 'Machine_learning',
        'Deep_learning', 'Natural_language_processing',
        'Computer_vision', 'Neural_network',
        'Large_language_model', 'Reinforcement_learning',
        'Artificial_general_intelligence', 'Computational_linguistics',
        'Robotics', 'Computer_science',
        'Data_science', 'Automation',
        'Technology', 'Innovation',
        'Big_data', 'Data_mining',
        'Supervised_learning', 'Unsupervised_learning',
        'Causal_inference', 'AutoML',
        'Generative_AI', 'Model_interpretability',
        'Data_visualization'
        ]

    ai_models = [
    # Computer Vision Models
    "ResNet",
    "YOLO (You Only Look Once)",
    "EfficientNet",
    "Mask R-CNN",
    "Inception",
    "VGGNet",
    "U-Net",
    "Swin Transformer",
    "DeepLabV3",
    "MobileNet",

    # Natural Language Processing (NLP) Models
    "BERT (Bidirectional Encoder Representations from Transformers)",
    "GPT-3 / GPT-4 (Generative Pre-trained Transformers)",
    "T5 (Text-to-Text Transfer Transformer)",
    "RoBERTa",
    "XLNet",
    "DistilBERT",
    "ALBERT",
    "BART (Bidirectional and Auto-Regressive Transformers)",
    "OpenAI Codex",
    "LaMDA (Language Model for Dialogue Applications)",

    # Reinforcement Learning (RL) Models
    "Deep Q-Network (DQN)",
    "AlphaGo",
    "AlphaZero",
    "A3C (Asynchronous Advantage Actor-Critic)",
    "PPO (Proximal Policy Optimization)",
    "TD3 (Twin Delayed Deep Deterministic Policy Gradient)",
    "SAC (Soft Actor-Critic)",
    "DeepMind's MuZero",

    # General Machine Learning (ML) Models
    "Random Forest",
    "Gradient Boosting Machines (GBM)",
    "Support Vector Machine (SVM)",
    "Logistic Regression",
    "K-Nearest Neighbors (KNN)",
    "Naive Bayes",
    "K-Means",
    "AdaBoost",
    "Linear/Polynomial Regression",

    # Generative Models
    "GANs (Generative Adversarial Networks)",
    "BigGAN",
    "VAE (Variational Autoencoders)",
    "StyleGAN",
    "DALL·E",
    "CLIP",
    "Stable Diffusion",

    # Speech and Audio Models
    "OpenAI Whisper",
    "DeepSpeech",
    "Tacotron 2",
    "Wav2Vec",
    "Vocoder",

    # Graph Neural Networks (GNN)
    "GCN (Graph Convolutional Networks)",
    "GAT (Graph Attention Networks)",
    "GraphSAGE"]

    seed_topics = ds_domains + ai_models

    print("Starting topic discovery and data collection...")
    all_topics, topic_metadata = collector.discover_related_topics(seed_topics, max_depth=2)
    print("Process complete!")

if __name__ == "__main__":
    main()
# Out:
# Streaming output truncated to the last 5000 lines.
# Successfully saved 3507 rows to /content/drive/MyDrive/AITrendAnalysis-project/wikipedia_data_with_categories.csv
# Saved batch of 3507 records
# Processing topic: Fooocus
# Successfully saved 228 rows to /content/drive/MyDrive/AITrendAnalysis-project/wikipedia_data_with_categories.csv
# Saved batch of 228 records
# Processing topic: Computer (magazine)
# Successfully saved 3524 rows to /content/drive/MyDrive/AITrendAnalysis-project/wikipedia_data_with_categories.csv
# Saved batch of 3524 records
# Processing topic: Fiber crop
# Successfully saved 3524 rows to /content/drive/MyDrive/AITrendAnalysis-project/wikipedia_data_with_categories.csv
# Saved batch of 3524 records
# Processing topic: Ethnomethodology
# Successfully saved 3524 rows to /content/drive/MyDrive/AITrendAnalysis-project/wikipedia_data_with_categories.csv
# Saved batch of 3524 records
# Processing topic: Electric power industry
# Successfully saved 3524 rows to /content/drive/MyDrive/AITrendAnalysis-project/wikipedia_data_with_categories.csv
# Saved batch of 3524 records
# Processing topic: Fuel oil
# Successfully saved 3524 rows to /content/drive/MyDrive/AITrendAnalysis-project/wikipedia_data_with_categories.csv
# Saved batch of 3524 records
# Processing topic: Artificial neural networks
# Successfully saved 3524 rows to /content/drive/MyDrive/AITrendAnalysis-project/wikipedia_data_with_categories.csv
# Saved batch of 3524 records
# Processing topic: Hallucination (artificial intelligence)
# Successfully saved 785 rows to /content/drive/MyDrive/AITrendAnalysis-project/wikipedia_data_with_categories.csv
# Saved batch of 785 records
# Processing topic: Insomnia (2002 film)
# Successfully saved 3524 rows to /content/drive/MyDrive/AITrendAnalysis-project/wikipedia_data_with_categories.csv
# Saved batch of 3524 records
# Processing topic: Systems management
# Successfully saved 3524 rows to /content/drive/MyDrive/AITrendAnalysis-project/wikipedia_data_with_categories.csv
# Saved batch of 3524 records
# Processing topic: Thesaurus (information retrieval)
# Successfully saved 3524 rows to /content/drive/MyDrive/AITrendAnalysis-project/wikipedia_data_with_categories.csv
# Saved batch of 3524 records
# Processing topic: DNA nanotechnology
# Successfully saved 3524 rows to /content/drive/MyDrive/AITrendAnalysis-project/wikipedia_data_with_categories.csv
# Saved batch of 3524 records
# Processing topic: Google Cloud Storage
# Successfully saved 3522 rows to /content/drive/MyDrive/AITrendAnalysis-project/wikipedia_data_with_categories.csv
# Saved batch of 3522 records
# Processing topic: Alexander Lerner
# Successfully saved 3524 rows to /content/drive/MyDrive/AITrendAnalysis-project/wikipedia_data_with_categories.csv
# Saved batch of 3524 records
# Processing topic: Jevons paradox
# Successfully saved 3524 rows to /content/drive/MyDrive/AITrendAnalysis-project/wikipedia_data_with_categories.csv
# Saved batch of 3524 records
# Processing topic: PID controller
# Successfully saved 3524 rows to /content/drive/MyDrive/AITrendAnalysis-project/wikipedia_data_with_categories.csv
# Saved batch of 3524 records
# Processing topic: Law enforcement in the United States
# Successfully saved 3524 rows to /content/drive/MyDrive/AITrendAnalysis-project/wikipedia_data_with_categories.csv
# Saved batch of 3524 records
# Processing topic: Gold mining
# Successfully saved 3524 rows to /content/drive/MyDrive/AITrendAnalysis-project/wikipedia_data_with_categories.csv
# Saved batch of 3524 records
# Processing topic: Australian Go Association
# Successfully saved 2992 rows to /content/drive/MyDrive/AITrendAnalysis-project/wikipedia_data_with_categories.csv
# Saved batch of 2992 records
# Processing topic: Philip S. Yu
# Successfully saved 3522 rows to /content/drive/MyDrive/AITrendAnalysis-project/wikipedia_data_with_categories.csv
# Saved batch of 3522 records
# Processing topic: Stemming
# Successfully saved 3524 rows to /content/drive/MyDrive/AITrendAnalysis-project/wikipedia_data_with_categories.csv
# Saved batch of 3524 records
# Processing topic: Civilization
# Successfully saved 3524 rows to /content/drive/MyDrive/AITrendAnalysis-project/wikipedia_data_with_categories.csv
# Saved batch of 3524 records
# Processing topic: Antipositivism
# Successfully saved 3524 rows to /content/drive/MyDrive/AITrendAnalysis-project/wikipedia_data_with_categories.csv
# Saved batch of 3524 records
# Processing topic: Germany
# Successfully saved 3524 rows to /content/drive/MyDrive/AITrendAnalysis-project/wikipedia_data_with_categories.csv
# Saved batch of 3524 records
# Processing topic: Seppo Linnainmaa
# Successfully saved 3255 rows to /content/drive/MyDrive/AITrendAnalysis-project/wikipedia_data_with_categories.csv
# Saved batch of 3255 records
# Processing topic: Automation technician
# Successfully saved 3346 rows to /content/drive/MyDrive/AITrendAnalysis-project/wikipedia_data_with_categories.csv
# Saved batch of 3346 records
# Processing topic: Vision transformer
# Successfully saved 1322 rows to /content/drive/MyDrive/AITrendAnalysis-project/wikipedia_data_with_categories.csv
# Saved batch of 1322 records
# Processing topic: Physical symbol system
# Successfully saved 3524 rows to /content/drive/MyDrive/AITrendAnalysis-project/wikipedia_data_with_categories.csv
# Saved batch of 3524 records
# Processing topic: Google Insights for Search
# Successfully saved 3524 rows to /content/drive/MyDrive/AITrendAnalysis-project/wikipedia_data_with_categories.csv
# Saved batch of 3524 records
# Processing topic: Bazel (software)
# Successfully saved 3168 rows to /content/drive/MyDrive/AITrendAnalysis-project/wikipedia_data_with_categories.csv
# Saved batch of 3168 records
# Processing topic: Language model
# Successfully saved 3524 rows to /content/drive/MyDrive/AITrendAnalysis-project/wikipedia_data_with_categories.csv
# Saved batch of 3524 records
# Processing topic: Category:Formal languages
# Successfully saved 3524 rows to /content/drive/MyDrive/AITrendAnalysis-project/wikipedia_data_with_categories.csv
# Saved batch of 3524 records
# Processing topic: General Architecture for Text Engineering
# Successfully saved 3524 rows to /content/drive/MyDrive/AITrendAnalysis-project/wikipedia_data_with_categories.csv
# Saved batch of 3524 records
# Processing topic: Philosophical Transactions of the Royal Society B
# Successfully saved 3524 rows to /content/drive/MyDrive/AITrendAnalysis-project/wikipedia_data_with_categories.csv
# Saved batch of 3524 records
# Processing topic: Cryptocurrency
# Successfully saved 3524 rows to /content/drive/MyDrive/AITrendAnalysis-project/wikipedia_data_with_categories.csv
# Saved batch of 3524 records
# Processing topic: Portmanteau
# Successfully saved 3524 rows to /content/drive/MyDrive/AITrendAnalysis-project/wikipedia_data_with_categories.csv
# Saved batch of 3524 records
# Processing topic: Cost-effectiveness analysis
# Successfully saved 3524 rows to /content/drive/MyDrive/AITrendAnalysis-project/wikipedia_data_with_categories.csv
# Saved batch of 3524 records
# Processing topic: Ceramic
# Successfully saved 3524 rows to /content/drive/MyDrive/AITrendAnalysis-project/wikipedia_data_with_categories.csv
# Saved batch of 3524 records
# Processing topic: Bloomberg News
# Successfully saved 3524 rows to /content/drive/MyDrive/AITrendAnalysis-project/wikipedia_data_with_categories.csv
# Saved batch of 3524 records
# Processing topic: Deepfakes
# Successfully saved 2545 rows to /content/drive/MyDrive/AITrendAnalysis-project/wikipedia_data_with_categories.csv
# Saved batch of 2545 records
# Processing topic: Google Reader
# Successfully saved 3524 rows to /content/drive/MyDrive/AITrendAnalysis-project/wikipedia_data_with_categories.csv
# Saved batch of 3524 records
# Processing topic: Thought experiment
# Successfully saved 3524 rows to /content/drive/MyDrive/AITrendAnalysis-project/wikipedia_data_with_categories.csv
# Saved batch of 3524 records
# Processing topic: Grammar
# Successfully saved 3524 rows to /content/drive/MyDrive/AITrendAnalysis-project/wikipedia_data_with_categories.csv
# Saved batch of 3524 records
# Processing topic: Bread
# Successfully saved 3524 rows to /content/drive/MyDrive/AITrendAnalysis-project/wikipedia_data_with_categories.csv
# Saved batch of 3524 records
# Processing topic: Autonomy of syntax
# Successfully saved 1480 rows to /content/drive/MyDrive/AITrendAnalysis-project/wikipedia_data_with_categories.csv
# Saved batch of 1480 records
# Processing topic: Robotics simulator
# Successfully saved 3524 rows to /content/drive/MyDrive/AITrendAnalysis-project/wikipedia_data_with_categories.csv
# Saved batch of 3524 records
# Processing topic: Cod fisheries
# Successfully saved 3524 rows to /content/drive/MyDrive/AITrendAnalysis-project/wikipedia_data_with_categories.csv
# Saved batch of 3524 records
# Processing topic: Social determinants of health
# Successfully saved 3524 rows to /content/drive/MyDrive/AITrendAnalysis-project/wikipedia_data_with_categories.csv
# Saved batch of 3524 records
# Processing topic: Hollywood Foreign Press Association
# Successfully saved 3524 rows to /content/drive/MyDrive/AITrendAnalysis-project/wikipedia_data_with_categories.csv
# Saved batch of 3524 records
# Processing topic: Discourse
# Successfully saved 3524 rows to /content/drive/MyDrive/AITrendAnalysis-project/wikipedia_data_with_categories.csv
# Saved batch of 3524 records
# Processing topic: Mining engineering
# Successfully saved 3524 rows to /content/drive/MyDrive/AITrendAnalysis-project/wikipedia_data_with_categories.csv
# Saved batch of 3524 records
# Processing topic: Analysis
# Successfully saved 3524 rows to /content/drive/MyDrive/AITrendAnalysis-project/wikipedia_data_with_categories.csv
# Saved batch of 3524 records
# Processing topic: Soft robotics
# Successfully saved 3197 rows to /content/drive/MyDrive/AITrendAnalysis-project/wikipedia_data_with_categories.csv
# Saved batch of 3197 records
# Processing topic: 3D optical data storage
# Successfully saved 3524 rows to /content/drive/MyDrive/AITrendAnalysis-project/wikipedia_data_with_categories.csv
# Saved batch of 3524 records
# Processing topic: Tsumego
# Successfully saved 3524 rows to /content/drive/MyDrive/AITrendAnalysis-project/wikipedia_data_with_categories.csv
# Saved batch of 3524 records
# Processing topic: Apache SystemML
# Successfully saved 3270 rows to /content/drive/MyDrive/AITrendAnalysis-project/wikipedia_data_with_categories.csv
# Saved batch of 3270 records
# Processing topic: Constructive realism
# Successfully saved 3524 rows to /content/drive/MyDrive/AITrendAnalysis-project/wikipedia_data_with_categories.csv
# Saved batch of 3524 records
# Processing topic: Emmett Shear
# Successfully saved 3524 rows to /content/drive/MyDrive/AITrendAnalysis-project/wikipedia_data_with_categories.csv
# Saved batch of 3524 records
# Processing topic: Alan Winfield
# Successfully saved 577 rows to /content/drive/MyDrive/AITrendAnalysis-project/wikipedia_data_with_categories.csv
# Saved batch of 577 records
# Processing topic: Multiplexing
# Successfully saved 3524 rows to /content/drive/MyDrive/AITrendAnalysis-project/wikipedia_data_with_categories.csv
# Saved batch of 3524 records
# Processing topic: American Economic Review
# Successfully saved 3524 rows to /content/drive/MyDrive/AITrendAnalysis-project/wikipedia_data_with_categories.csv
# Saved batch of 3524 records
# Processing topic: Category:Articles containing potentially dated statements from August 2012
# Successfully saved 3523 rows to /content/drive/MyDrive/AITrendAnalysis-project/wikipedia_data_with_categories.csv
# Saved batch of 3523 records
# Processing topic: False negative rate
# Successfully saved 3518 rows to /content/drive/MyDrive/AITrendAnalysis-project/wikipedia_data_with_categories.csv
# Saved batch of 3518 records
# Processing topic: Extreme programming
# Successfully saved 3524 rows to /content/drive/MyDrive/AITrendAnalysis-project/wikipedia_data_with_categories.csv
# Saved batch of 3524 records
# Processing topic: Cpplint
# Successfully saved 3524 rows to /content/drive/MyDrive/AITrendAnalysis-project/wikipedia_data_with_categories.csv
# Saved batch of 3524 records
# Processing topic: Electronic oscillator
# Successfully saved 3524 rows to /content/drive/MyDrive/AITrendAnalysis-project/wikipedia_data_with_categories.csv
# Saved batch of 3524 records
# Processing topic: Java (programming language)
# Successfully saved 3524 rows to /content/drive/MyDrive/AITrendAnalysis-project/wikipedia_data_with_categories.csv
# Saved batch of 3524 records
# Processing topic: Impossible object
# Successfully saved 3524 rows to /content/drive/MyDrive/AITrendAnalysis-project/wikipedia_data_with_categories.csv
# Saved batch of 3524 records
# Processing topic: Video motion analysis
# Successfully saved 3524 rows to /content/drive/MyDrive/AITrendAnalysis-project/wikipedia_data_with_categories.csv
# Saved batch of 3524 records
# Processing topic: Initiative (chess)
# Successfully saved 3524 rows to /content/drive/MyDrive/AITrendAnalysis-project/wikipedia_data_with_categories.csv
# Saved batch of 3524 records
# Processing topic: Behaviorism
# Successfully saved 3524 rows to /content/drive/MyDrive/AITrendAnalysis-project/wikipedia_data_with_categories.csv
# Saved batch of 3524 records
# Processing topic: Adam Valdez
# Successfully saved 2946 rows to /content/drive/MyDrive/AITrendAnalysis-project/wikipedia_data_with_categories.csv
# Saved batch of 2946 records
# Processing topic: Electric generator
# Successfully saved 3524 rows to /content/drive/MyDrive/AITrendAnalysis-project/wikipedia_data_with_categories.csv
# Saved batch of 3524 records
# Processing topic: Google News & Weather
# Successfully saved 3524 rows to /content/drive/MyDrive/AITrendAnalysis-project/wikipedia_data_with_categories.csv
# Saved batch of 3524 records
# Processing topic: LMU Munich
# Successfully saved 3515 rows to /content/drive/MyDrive/AITrendAnalysis-project/wikipedia_data_with_categories.csv
# Saved batch of 3515 records
# Processing topic: Semantic analysis (machine learning)
# Successfully saved 3524 rows to /content/drive/MyDrive/AITrendAnalysis-project/wikipedia_data_with_categories.csv
# Saved batch of 3524 records
# Processing topic: Herbert Robbins
# Successfully saved 3524 rows to /content/drive/MyDrive/AITrendAnalysis-project/wikipedia_data_with_categories.csv
# Saved batch of 3524 records
# Processing topic: Metaverse
# Successfully saved 3524 rows to /content/drive/MyDrive/AITrendAnalysis-project/wikipedia_data_with_categories.csv
# Saved batch of 3524 records
# Processing topic: Tuo Jiaxi
# Successfully saved 3300 rows to /content/drive/MyDrive/AITrendAnalysis-project/wikipedia_data_with_categories.csv
# Saved batch of 3300 records
# Processing topic: Self-organizing map
# Successfully saved 3524 rows to /content/drive/MyDrive/AITrendAnalysis-project/wikipedia_data_with_categories.csv
# Saved batch of 3524 records
# Processing topic: Autonomy
# Successfully saved 3524 rows to /content/drive/MyDrive/AITrendAnalysis-project/wikipedia_data_with_categories.csv
# Saved batch of 3524 records
# Processing topic: Gerd Nefzer
# Successfully saved 2582 rows to /content/drive/MyDrive/AITrendAnalysis-project/wikipedia_data_with_categories.csv
# Saved batch of 2582 records
# Processing topic: Category:Articles needing additional references from July 2019
# Successfully saved 2065 rows to /content/drive/MyDrive/AITrendAnalysis-project/wikipedia_data_with_categories.csv
# Saved batch of 2065 records
# Processing topic: Chief technology officer
# Successfully saved 3524 rows to /content/drive/MyDrive/AITrendAnalysis-project/wikipedia_data_with_categories.csv
# Saved batch of 3524 records
# Processing topic: Network performance
# Successfully saved 3524 rows to /content/drive/MyDrive/AITrendAnalysis-project/wikipedia_data_with_categories.csv
# Saved batch of 3524 records
# Processing topic: Formalism (linguistics)
# Successfully saved 3452 rows to /content/drive/MyDrive/AITrendAnalysis-project/wikipedia_data_with_categories.csv
# Saved batch of 3452 records
# Processing topic: LIONsolver
# Successfully saved 3523 rows to /content/drive/MyDrive/AITrendAnalysis-project/wikipedia_data_with_categories.csv
# Saved batch of 3523 records
# Processing topic: Example-based machine translation
# Successfully saved 3524 rows to /content/drive/MyDrive/AITrendAnalysis-project/wikipedia_data_with_categories.csv
# Saved batch of 3524 records
# Processing topic: Alvin Goldman
# Successfully saved 3524 rows to /content/drive/MyDrive/AITrendAnalysis-project/wikipedia_data_with_categories.csv
# Saved batch of 3524 records
# Processing topic: Category:Linguistics
# Successfully saved 3524 rows to /content/drive/MyDrive/AITrendAnalysis-project/wikipedia_data_with_categories.csv
# Saved batch of 3524 records
# Processing topic: Sparse matrix
# Successfully saved 3524 rows to /content/drive/MyDrive/AITrendAnalysis-project/wikipedia_data_with_categories.csv
# Saved batch of 3524 records
# Processing topic: Glossary of areas of mathematics
# Successfully saved 3524 rows to /content/drive/MyDrive/AITrendAnalysis-project/wikipedia_data_with_categories.csv
# Saved batch of 3524 records
# Processing topic: Glossary of chess problems
# Successfully saved 3524 rows to /content/drive/MyDrive/AITrendAnalysis-project/wikipedia_data_with_categories.csv
# Saved batch of 3524 records
# Processing topic: Aardvark (search engine)
# Successfully saved 3524 rows to /content/drive/MyDrive/AITrendAnalysis-project/wikipedia_data_with_categories.csv
# Saved batch of 3524 records
# Processing topic: Glass OS
# Successfully saved 2884 rows to /content/drive/MyDrive/AITrendAnalysis-project/wikipedia_data_with_categories.csv
# Saved batch of 2884 records
# Processing topic: Biological warfare
# Successfully saved 3524 rows to /content/drive/MyDrive/AITrendAnalysis-project/wikipedia_data_with_categories.csv
# Saved batch of 3524 records
# Processing topic: Automation engineering
# Successfully saved 3524 rows to /content/drive/MyDrive/AITrendAnalysis-project/wikipedia_data_with_categories.csv
# Saved batch of 3524 records
# Processing topic: Russ Salakhutdinov
# Successfully saved 2994 rows to /content/drive/MyDrive/AITrendAnalysis-project/wikipedia_data_with_categories.csv
# Saved batch of 2994 records
# Processing topic: Datasaurus dozen
# Successfully saved 391 rows to /content/drive/MyDrive/AITrendAnalysis-project/wikipedia_data_with_categories.csv
# Saved batch of 391 records
# Processing topic: Norbit module
# Successfully saved 1906 rows to /content/drive/MyDrive/AITrendAnalysis-project/wikipedia_data_with_categories.csv
# Saved batch of 1906 records
# Processing topic: Molecular assembler
# Successfully saved 3524 rows to /content/drive/MyDrive/AITrendAnalysis-project/wikipedia_data_with_categories.csv
# Saved batch of 3524 records
# Processing topic: Companion robot
# Successfully saved 2424 rows to /content/drive/MyDrive/AITrendAnalysis-project/wikipedia_data_with_categories.csv
# Saved batch of 2424 records
# Processing topic: Deep Fritz
# Successfully saved 3519 rows to /content/drive/MyDrive/AITrendAnalysis-project/wikipedia_data_with_categories.csv
# Saved batch of 3519 records
# Processing topic: Entertainment
# Successfully saved 3524 rows to /content/drive/MyDrive/AITrendAnalysis-project/wikipedia_data_with_categories.csv
# Saved batch of 3524 records
# Processing topic: Heuristic
# Successfully saved 3524 rows to /content/drive/MyDrive/AITrendAnalysis-project/wikipedia_data_with_categories.csv
# Saved batch of 3524 records
# Processing topic: Statement on AI risk of extinction
# Successfully saved 634 rows to /content/drive/MyDrive/AITrendAnalysis-project/wikipedia_data_with_categories.csv
# Saved batch of 634 records
# Processing topic: Journal of the Audio Engineering Society
# Successfully saved 2415 rows to /content/drive/MyDrive/AITrendAnalysis-project/wikipedia_data_with_categories.csv
# Saved batch of 2415 records
# Processing topic: Google Fit
# Successfully saved 3524 rows to /content/drive/MyDrive/AITrendAnalysis-project/wikipedia_data_with_categories.csv
# Saved batch of 3524 records
# Processing topic: LCCN (identifier)
# Successfully saved 1786 rows to /content/drive/MyDrive/AITrendAnalysis-project/wikipedia_data_with_categories.csv
# Saved batch of 1786 records
# Processing topic: Daniel Huttenlocher
# Successfully saved 1080 rows to /content/drive/MyDrive/AITrendAnalysis-project/wikipedia_data_with_categories.csv
# Saved batch of 1080 records
# Processing topic: Health Insurance Portability and Accountability Act
# Successfully saved 3524 rows to /content/drive/MyDrive/AITrendAnalysis-project/wikipedia_data_with_categories.csv
# Saved batch of 3524 records
# Processing topic: Google Digital Garage
# Successfully saved 1199 rows to /content/drive/MyDrive/AITrendAnalysis-project/wikipedia_data_with_categories.csv
# Saved batch of 1199 records
# Processing topic: Metadata
# Successfully saved 3524 rows to /content/drive/MyDrive/AITrendAnalysis-project/wikipedia_data_with_categories.csv
# Saved batch of 3524 records
# Processing topic: Computer science (disambiguation)
# Successfully saved 1189 rows to /content/drive/MyDrive/AITrendAnalysis-project/wikipedia_data_with_categories.csv
# Saved batch of 1189 records
# Processing topic: Computer animation
# Successfully saved 3524 rows to /content/drive/MyDrive/AITrendAnalysis-project/wikipedia_data_with_categories.csv
# Saved batch of 3524 records
# Processing topic: Algorithmic transparency
# Successfully saved 2442 rows to /content/drive/MyDrive/AITrendAnalysis-project/wikipedia_data_with_categories.csv
# Saved batch of 2442 records
# Processing topic: Google Checkout
# Successfully saved 3524 rows to /content/drive/MyDrive/AITrendAnalysis-project/wikipedia_data_with_categories.csv
# Saved batch of 3524 records
# Processing topic: Harley Jessup
# Successfully saved 3524 rows to /content/drive/MyDrive/AITrendAnalysis-project/wikipedia_data_with_categories.csv
# Saved batch of 3524 records
# Processing topic: Pro-drop language
# Successfully saved 3524 rows to /content/drive/MyDrive/AITrendAnalysis-project/wikipedia_data_with_categories.csv
# Saved batch of 3524 records
# Processing topic: Dynamics (physics)
# Successfully saved 3524 rows to /content/drive/MyDrive/AITrendAnalysis-project/wikipedia_data_with_categories.csv
# Saved batch of 3524 records
# Processing topic: Health system
# Successfully saved 3524 rows to /content/drive/MyDrive/AITrendAnalysis-project/wikipedia_data_with_categories.csv
# Saved batch of 3524 records
# Processing topic: Chen Yutian
# Successfully saved 2771 rows to /content/drive/MyDrive/AITrendAnalysis-project/wikipedia_data_with_categories.csv
# Saved batch of 2771 records
# Processing topic: Glossary of civil engineering
# Successfully saved 3158 rows to /content/drive/MyDrive/AITrendAnalysis-project/wikipedia_data_with_categories.csv
# Saved batch of 3158 records
# Processing topic: Automated species identification
# Successfully saved 3524 rows to /content/drive/MyDrive/AITrendAnalysis-project/wikipedia_data_with_categories.csv
# Saved batch of 3524 records
# Processing topic: Cloze test
# Successfully saved 3524 rows to /content/drive/MyDrive/AITrendAnalysis-project/wikipedia_data_with_categories.csv
# Saved batch of 3524 records
# Processing topic: Gerhard Neumann
# Successfully saved 3524 rows to /content/drive/MyDrive/AITrendAnalysis-project/wikipedia_data_with_categories.csv
# Saved batch of 3524 records
# Processing topic: Roomba
# Successfully saved 3524 rows to /content/drive/MyDrive/AITrendAnalysis-project/wikipedia_data_with_categories.csv
# Saved batch of 3524 records
# Processing topic: Adobe Firefly
# Successfully saved 604 rows to /content/drive/MyDrive/AITrendAnalysis-project/wikipedia_data_with_categories.csv
# Saved batch of 604 records
# Processing topic: Transistor
# Successfully saved 3524 rows to /content/drive/MyDrive/AITrendAnalysis-project/wikipedia_data_with_categories.csv
# Saved batch of 3524 records
# Processing topic: Helen Toner
# Successfully saved 459 rows to /content/drive/MyDrive/AITrendAnalysis-project/wikipedia_data_with_categories.csv
# Saved batch of 459 records
# Processing topic: Smart grid
# Successfully saved 3524 rows to /content/drive/MyDrive/AITrendAnalysis-project/wikipedia_data_with_categories.csv
# Saved batch of 3524 records
# Processing topic: Muscle cell
# Successfully saved 3524 rows to /content/drive/MyDrive/AITrendAnalysis-project/wikipedia_data_with_categories.csv
# Saved batch of 3524 records
# Processing topic: Self-supervised learning
# Successfully saved 1306 rows to /content/drive/MyDrive/AITrendAnalysis-project/wikipedia_data_with_categories.csv
# Saved batch of 1306 records
# Processing topic: Go stones
# Successfully saved 2424 rows to /content/drive/MyDrive/AITrendAnalysis-project/wikipedia_data_with_categories.csv
# Saved batch of 2424 records
# Processing topic: Google Schemer
# Successfully saved 3521 rows to /content/drive/MyDrive/AITrendAnalysis-project/wikipedia_data_with_categories.csv
# Saved batch of 3521 records
# Processing topic: Sibilance
# Successfully saved 3523 rows to /content/drive/MyDrive/AITrendAnalysis-project/wikipedia_data_with_categories.csv
# Saved batch of 3523 records
# Processing topic: Black box
# Successfully saved 3524 rows to /content/drive/MyDrive/AITrendAnalysis-project/wikipedia_data_with_categories.csv
# Saved batch of 3524 records
# Processing topic: Off-target
# Successfully saved 2470 rows to /content/drive/MyDrive/AITrendAnalysis-project/wikipedia_data_with_categories.csv
# Saved batch of 2470 records
# Processing topic: Forensic science
# Successfully saved 3524 rows to /content/drive/MyDrive/AITrendAnalysis-project/wikipedia_data_with_categories.csv
# Saved batch of 3524 records
# Processing topic: Synthetic aperture sonar
# Successfully saved 3524 rows to /content/drive/MyDrive/AITrendAnalysis-project/wikipedia_data_with_categories.csv
# Saved batch of 3524 records
# Processing topic: Ambiguous
# Successfully saved 3524 rows to /content/drive/MyDrive/AITrendAnalysis-project/wikipedia_data_with_categories.csv
# Saved batch of 3524 records
# Processing topic: Array data structure
# Successfully saved 3524 rows to /content/drive/MyDrive/AITrendAnalysis-project/wikipedia_data_with_categories.csv
# Saved batch of 3524 records
# Processing topic: Category:Datasets in computer vision
# Successfully saved 3449 rows to /content/drive/MyDrive/AITrendAnalysis-project/wikipedia_data_with_categories.csv
# Saved batch of 3449 records
# Processing topic: Causal model
# Successfully saved 3524 rows to /content/drive/MyDrive/AITrendAnalysis-project/wikipedia_data_with_categories.csv
# Saved batch of 3524 records
# Processing topic: AlphaStar (software)
# Successfully saved 2214 rows to /content/drive/MyDrive/AITrendAnalysis-project/wikipedia_data_with_categories.csv
# Saved batch of 2214 records
# Processing topic: Generative model
# Successfully saved 3524 rows to /content/drive/MyDrive/AITrendAnalysis-project/wikipedia_data_with_categories.csv
# Saved batch of 3524 records
# Processing topic: Chicago Tribune
# Successfully saved 3524 rows to /content/drive/MyDrive/AITrendAnalysis-project/wikipedia_data_with_categories.csv
# Saved batch of 3524 records
# Processing topic: Data model
# Successfully saved 3524 rows to /content/drive/MyDrive/AITrendAnalysis-project/wikipedia_data_with_categories.csv
# Saved batch of 3524 records
# Processing topic: Comparison of deep learning software
# Successfully saved 3322 rows to /content/drive/MyDrive/AITrendAnalysis-project/wikipedia_data_with_categories.csv
# Saved batch of 3322 records
# Processing topic: Jill Lepore
# Successfully saved 3524 rows to /content/drive/MyDrive/AITrendAnalysis-project/wikipedia_data_with_categories.csv
# Saved batch of 3524 records
# Processing topic: Google Keep
# Successfully saved 3524 rows to /content/drive/MyDrive/AITrendAnalysis-project/wikipedia_data_with_categories.csv
# Saved batch of 3524 records
# Processing topic: Automotive engineering
# Successfully saved 3524 rows to /content/drive/MyDrive/AITrendAnalysis-project/wikipedia_data_with_categories.csv
# Saved batch of 3524 records
# Processing topic: Directed acyclic graph
# Successfully saved 3524 rows to /content/drive/MyDrive/AITrendAnalysis-project/wikipedia_data_with_categories.csv
# Saved batch of 3524 records
# Processing topic: Clay pit
# Successfully saved 3524 rows to /content/drive/MyDrive/AITrendAnalysis-project/wikipedia_data_with_categories.csv
# Saved batch of 3524 records
# Processing topic: Manufacturing processes
# Successfully saved 2822 rows to /content/drive/MyDrive/AITrendAnalysis-project/wikipedia_data_with_categories.csv
# Saved batch of 2822 records
# Processing topic: Functional specification
# Successfully saved 3524 rows to /content/drive/MyDrive/AITrendAnalysis-project/wikipedia_data_with_categories.csv
# Saved batch of 3524 records
# Processing topic: JSON
# Successfully saved 3524 rows to /content/drive/MyDrive/AITrendAnalysis-project/wikipedia_data_with_categories.csv
# Saved batch of 3524 records
# Processing topic: Lighthill report
# Successfully saved 3524 rows to /content/drive/MyDrive/AITrendAnalysis-project/wikipedia_data_with_categories.csv
# Saved batch of 3524 records
# Processing topic: Diminishing returns
# Successfully saved 3524 rows to /content/drive/MyDrive/AITrendAnalysis-project/wikipedia_data_with_categories.csv
# Saved batch of 3524 records
# Processing topic: Asilomar Conference on Beneficial AI
# Successfully saved 2633 rows to /content/drive/MyDrive/AITrendAnalysis-project/wikipedia_data_with_categories.csv
# Saved batch of 2633 records
# Processing topic: Structure from motion
# Successfully saved 3524 rows to /content/drive/MyDrive/AITrendAnalysis-project/wikipedia_data_with_categories.csv
# Saved batch of 3524 records
# Processing topic: Factor 10
# Successfully saved 3524 rows to /content/drive/MyDrive/AITrendAnalysis-project/wikipedia_data_with_categories.csv
# Saved batch of 3524 records
# Processing topic: Bioconservatism
# Successfully saved 3524 rows to /content/drive/MyDrive/AITrendAnalysis-project/wikipedia_data_with_categories.csv
# Saved batch of 3524 records
# Processing topic: Miniature effect
# Successfully saved 3524 rows to /content/drive/MyDrive/AITrendAnalysis-project/wikipedia_data_with_categories.csv
# Saved batch of 3524 records
# Processing topic: Google Energy
# Successfully saved 3523 rows to /content/drive/MyDrive/AITrendAnalysis-project/wikipedia_data_with_categories.csv
# Saved batch of 3523 records
# Processing topic: Behavior informatics
# Successfully saved 3227 rows to /content/drive/MyDrive/AITrendAnalysis-project/wikipedia_data_with_categories.csv
# Saved batch of 3227 records
# Processing topic: DNA microarray
# Successfully saved 3524 rows to /content/drive/MyDrive/AITrendAnalysis-project/wikipedia_data_with_categories.csv
# Saved batch of 3524 records
# Processing topic: Isolation forest
# Successfully saved 1972 rows to /content/drive/MyDrive/AITrendAnalysis-project/wikipedia_data_with_categories.csv
# Saved batch of 1972 records
# Processing topic: Simulation software
# Successfully saved 3524 rows to /content/drive/MyDrive/AITrendAnalysis-project/wikipedia_data_with_categories.csv
# Saved batch of 3524 records
# Processing topic: Entertainment Weekly
# Successfully saved 3524 rows to /content/drive/MyDrive/AITrendAnalysis-project/wikipedia_data_with_categories.csv
# Saved batch of 3524 records
# Processing topic: Glial cells
# Successfully saved 3524 rows to /content/drive/MyDrive/AITrendAnalysis-project/wikipedia_data_with_categories.csv
# Saved batch of 3524 records
# Processing topic: Cargo
# Successfully saved 3524 rows to /content/drive/MyDrive/AITrendAnalysis-project/wikipedia_data_with_categories.csv
# Saved batch of 3524 records
# Processing topic: Depth map
# Successfully saved 3524 rows to /content/drive/MyDrive/AITrendAnalysis-project/wikipedia_data_with_categories.csv
# Saved batch of 3524 records
# Processing topic: Wikipedia:Notability
# Successfully saved 3524 rows to /content/drive/MyDrive/AITrendAnalysis-project/wikipedia_data_with_categories.csv
# Saved batch of 3524 records
# Processing topic: Charlemagne chessmen
# Successfully saved 962 rows to /content/drive/MyDrive/AITrendAnalysis-project/wikipedia_data_with_categories.csv
# Saved batch of 962 records
# Processing topic: Artificial consciousness
# Successfully saved 3524 rows to /content/drive/MyDrive/AITrendAnalysis-project/wikipedia_data_with_categories.csv
# Saved batch of 3524 records
# Processing topic: History of cloud computing
# Successfully saved 861 rows to /content/drive/MyDrive/AITrendAnalysis-project/wikipedia_data_with_categories.csv
# Saved batch of 861 records
# Processing topic: Key-agreement protocol
# Successfully saved 3524 rows to /content/drive/MyDrive/AITrendAnalysis-project/wikipedia_data_with_categories.csv
# Saved batch of 3524 records
# Processing topic: Linguistic prescription
# Successfully saved 3524 rows to /content/drive/MyDrive/AITrendAnalysis-project/wikipedia_data_with_categories.csv
# Saved batch of 3524 records
# Processing topic: Fantastic Voyage
# Successfully saved 3524 rows to /content/drive/MyDrive/AITrendAnalysis-project/wikipedia_data_with_categories.csv
# Saved batch of 3524 records
# Processing topic: Database model
# Successfully saved 3524 rows to /content/drive/MyDrive/AITrendAnalysis-project/wikipedia_data_with_categories.csv
# Saved batch of 3524 records
# Processing topic: Wikipedia:Mainspace
# Successfully saved 3524 rows to /content/drive/MyDrive/AITrendAnalysis-project/wikipedia_data_with_categories.csv
# Saved batch of 3524 records
# Processing topic: Actuator
# Successfully saved 3524 rows to /content/drive/MyDrive/AITrendAnalysis-project/wikipedia_data_with_categories.csv
# Saved batch of 3524 records
# Processing topic: Template:Differentiable computing
# Successfully saved 1704 rows to /content/drive/MyDrive/AITrendAnalysis-project/wikipedia_data_with_categories.csv
# Saved batch of 1704 records
# Processing topic: Fur clothing
# Successfully saved 3524 rows to /content/drive/MyDrive/AITrendAnalysis-project/wikipedia_data_with_categories.csv
# Saved batch of 3524 records
# Processing topic: New Scientist
# Successfully saved 3524 rows to /content/drive/MyDrive/AITrendAnalysis-project/wikipedia_data_with_categories.csv
# Saved batch of 3524 records
# Processing topic: Federal Trade Commission
# Successfully saved 3524 rows to /content/drive/MyDrive/AITrendAnalysis-project/wikipedia_data_with_categories.csv
# Saved batch of 3524 records
# Processing topic: Google Clips
# Successfully saved 2696 rows to /content/drive/MyDrive/AITrendAnalysis-project/wikipedia_data_with_categories.csv
# Saved batch of 2696 records
# Processing topic: Oliver Evans
# Successfully saved 3524 rows to /content/drive/MyDrive/AITrendAnalysis-project/wikipedia_data_with_categories.csv
# Saved batch of 3524 records
# Processing topic: Disability robot
# Successfully saved 3524 rows to /content/drive/MyDrive/AITrendAnalysis-project/wikipedia_data_with_categories.csv
# Saved batch of 3524 records
# Processing topic: Geography of robotics
# Successfully saved 3524 rows to /content/drive/MyDrive/AITrendAnalysis-project/wikipedia_data_with_categories.csv
# Saved batch of 3524 records
# Processing topic: Error-driven learning
# Successfully saved 3506 rows to /content/drive/MyDrive/AITrendAnalysis-project/wikipedia_data_with_categories.csv
# Saved batch of 3506 records
# Processing topic: Post-scarcity
# Successfully saved 3524 rows to /content/drive/MyDrive/AITrendAnalysis-project/wikipedia_data_with_categories.csv
# Saved batch of 3524 records
# Processing topic: Knowledge graph embedding
# Successfully saved 1345 rows to /content/drive/MyDrive/AITrendAnalysis-project/wikipedia_data_with_categories.csv
# Saved batch of 1345 records
# Processing topic: Data privacy
# Successfully saved 3524 rows to /content/drive/MyDrive/AITrendAnalysis-project/wikipedia_data_with_categories.csv
# Saved batch of 3524 records
# Processing topic: High-throughput computing
# Successfully saved 3524 rows to /content/drive/MyDrive/AITrendAnalysis-project/wikipedia_data_with_categories.csv
# Saved batch of 3524 records
# Processing topic: BAuA
# Successfully saved 2832 rows to /content/drive/MyDrive/AITrendAnalysis-project/wikipedia_data_with_categories.csv
# Saved batch of 2832 records
# Processing topic: Guy Hendrix Dyas
# Successfully saved 3524 rows to /content/drive/MyDrive/AITrendAnalysis-project/wikipedia_data_with_categories.csv
# Saved batch of 3524 records
# Processing topic: Category:Use dmy dates from August 2023
# Successfully saved 591 rows to /content/drive/MyDrive/AITrendAnalysis-project/wikipedia_data_with_categories.csv
# Saved batch of 591 records
# Processing topic: BBC News
# Successfully saved 3524 rows to /content/drive/MyDrive/AITrendAnalysis-project/wikipedia_data_with_categories.csv
# Saved batch of 3524 records
# Processing topic: Extract, transform, load
# Successfully saved 3524 rows to /content/drive/MyDrive/AITrendAnalysis-project/wikipedia_data_with_categories.csv
# Saved batch of 3524 records
# Processing topic: FarmWise
# Successfully saved 1498 rows to /content/drive/MyDrive/AITrendAnalysis-project/wikipedia_data_with_categories.csv
# Saved batch of 1498 records
# Processing topic: Google Hacks
# Successfully saved 3524 rows to /content/drive/MyDrive/AITrendAnalysis-project/wikipedia_data_with_categories.csv
# Saved batch of 3524 records
# Processing topic: Fitbit
# Successfully saved 3524 rows to /content/drive/MyDrive/AITrendAnalysis-project/wikipedia_data_with_categories.csv
# Saved batch of 3524 records
# Processing topic: CollegeHumor
# Successfully saved 3524 rows to /content/drive/MyDrive/AITrendAnalysis-project/wikipedia_data_with_categories.csv
# Saved batch of 3524 records
# Processing topic: Field-effect transistor
# Successfully saved 3524 rows to /content/drive/MyDrive/AITrendAnalysis-project/wikipedia_data_with_categories.csv
# Saved batch of 3524 records
# Processing topic: Kristin Thompson
# Successfully saved 3524 rows to /content/drive/MyDrive/AITrendAnalysis-project/wikipedia_data_with_categories.csv
# Saved batch of 3524 records
# Processing topic: AlphaFold
# Successfully saved 2127 rows to /content/drive/MyDrive/AITrendAnalysis-project/wikipedia_data_with_categories.csv
# Saved batch of 2127 records
# Processing topic: Graduate student
# Successfully saved 3524 rows to /content/drive/MyDrive/AITrendAnalysis-project/wikipedia_data_with_categories.csv
# Saved batch of 3524 records
# Processing topic: Muscle
# Successfully saved 3524 rows to /content/drive/MyDrive/AITrendAnalysis-project/wikipedia_data_with_categories.csv
# Saved batch of 3524 records
# Processing topic: Morocco
# Successfully saved 3524 rows to /content/drive/MyDrive/AITrendAnalysis-project/wikipedia_data_with_categories.csv
# Saved batch of 3524 records
# Processing topic: Data archaeology
# Successfully saved 3524 rows to /content/drive/MyDrive/AITrendAnalysis-project/wikipedia_data_with_categories.csv
# Saved batch of 3524 records
# Processing topic: Object recognition
# Successfully saved 3524 rows to /content/drive/MyDrive/AITrendAnalysis-project/wikipedia_data_with_categories.csv
# Saved batch of 3524 records
# Processing topic: Speech corpus
# Successfully saved 3524 rows to /content/drive/MyDrive/AITrendAnalysis-project/wikipedia_data_with_categories.csv
# Saved batch of 3524 records
# Processing topic: Google Input Tools
# Successfully saved 893 rows to /content/drive/MyDrive/AITrendAnalysis-project/wikipedia_data_with_categories.csv
# Saved batch of 893 records
# Processing topic: Artificial intelligence engineering
# Successfully saved 120 rows to /content/drive/MyDrive/AITrendAnalysis-project/wikipedia_data_with_categories.csv
# Saved batch of 120 records
# Processing topic: Chess.com Computer Chess Championship
# Successfully saved 1070 rows to /content/drive/MyDrive/AITrendAnalysis-project/wikipedia_data_with_categories.csv
# Saved batch of 1070 records
# Processing topic: The Conversation (website)
# Successfully saved 3524 rows to /content/drive/MyDrive/AITrendAnalysis-project/wikipedia_data_with_categories.csv
# Saved batch of 3524 records
# Processing topic: Jon Thum
# Successfully saved 3503 rows to /content/drive/MyDrive/AITrendAnalysis-project/wikipedia_data_with_categories.csv
# Saved batch of 3503 records
# Processing topic: Ensemble methods
# Successfully saved 1159 rows to /content/drive/MyDrive/AITrendAnalysis-project/wikipedia_data_with_categories.csv
# Saved batch of 1159 records
# Processing topic: Unvoiced
# Successfully saved 3510 rows to /content/drive/MyDrive/AITrendAnalysis-project/wikipedia_data_with_categories.csv
# Saved batch of 3510 records
# Processing topic: ACM Conference on Fairness, Accountability, and Transparency
# Successfully saved 2211 rows to /content/drive/MyDrive/AITrendAnalysis-project/wikipedia_data_with_categories.csv
# Saved batch of 2211 records
# Processing topic: Wikipedia:Common name
# Successfully saved 3442 rows to /content/drive/MyDrive/AITrendAnalysis-project/wikipedia_data_with_categories.csv
# Saved batch of 3442 records
# Processing topic: Intractable problem
# Successfully saved 2388 rows to /content/drive/MyDrive/AITrendAnalysis-project/wikipedia_data_with_categories.csv
# Saved batch of 2388 records
# Processing topic: Data preservation
# Successfully saved 2636 rows to /content/drive/MyDrive/AITrendAnalysis-project/wikipedia_data_with_categories.csv
# Saved batch of 2636 records
# Processing topic: Alfred North Whitehead
# Successfully saved 3524 rows to /content/drive/MyDrive/AITrendAnalysis-project/wikipedia_data_with_categories.csv
# Saved batch of 3524 records
# Processing topic: Economic productivity
# Successfully saved 3454 rows to /content/drive/MyDrive/AITrendAnalysis-project/wikipedia_data_with_categories.csv
# Saved batch of 3454 records
# Processing topic: Industrial Revolution
# Successfully saved 3524 rows to /content/drive/MyDrive/AITrendAnalysis-project/wikipedia_data_with_categories.csv
# Saved batch of 3524 records
# Processing topic: Estimation theory
# Successfully saved 3524 rows to /content/drive/MyDrive/AITrendAnalysis-project/wikipedia_data_with_categories.csv
# Saved batch of 3524 records
# Processing topic: Taisha jōseki
# Successfully saved 2460 rows to /content/drive/MyDrive/AITrendAnalysis-project/wikipedia_data_with_categories.csv
# Saved batch of 2460 records
# Processing topic: Pragmatics
# Successfully saved 3524 rows to /content/drive/MyDrive/AITrendAnalysis-project/wikipedia_data_with_categories.csv
# Saved batch of 3524 records
# Processing topic: Social inequality
# Successfully saved 3524 rows to /content/drive/MyDrive/AITrendAnalysis-project/wikipedia_data_with_categories.csv
# Saved batch of 3524 records
# Processing topic: Algebraic notation (chess)
# Successfully saved 3524 rows to /content/drive/MyDrive/AITrendAnalysis-project/wikipedia_data_with_categories.csv
# Saved batch of 3524 records
# Processing topic: Email
# Successfully saved 3524 rows to /content/drive/MyDrive/AITrendAnalysis-project/wikipedia_data_with_categories.csv
# Saved batch of 3524 records
# Processing topic: Event detection
# Successfully saved 976 rows to /content/drive/MyDrive/AITrendAnalysis-project/wikipedia_data_with_categories.csv
# Saved batch of 976 records
# Processing topic: Software verification and validation
# Successfully saved 3524 rows to /content/drive/MyDrive/AITrendAnalysis-project/wikipedia_data_with_categories.csv
# Saved batch of 3524 records
# Processing topic: Vowel
# Successfully saved 3524 rows to /content/drive/MyDrive/AITrendAnalysis-project/wikipedia_data_with_categories.csv
# Saved batch of 3524 records
# Processing topic: Doctor (title)
# Successfully saved 3524 rows to /content/drive/MyDrive/AITrendAnalysis-project/wikipedia_data_with_categories.csv
# Saved batch of 3524 records
# Processing topic: Natural gas
# Successfully saved 3524 rows to /content/drive/MyDrive/AITrendAnalysis-project/wikipedia_data_with_categories.csv
# Saved batch of 3524 records
# Processing topic: Data transmission
# Successfully saved 3524 rows to /content/drive/MyDrive/AITrendAnalysis-project/wikipedia_data_with_categories.csv
# Saved batch of 3524 records
# Processing topic: Climbing
# Successfully saved 3524 rows to /content/drive/MyDrive/AITrendAnalysis-project/wikipedia_data_with_categories.csv
# Saved batch of 3524 records
# Processing topic: Software design
# Successfully saved 3524 rows to /content/drive/MyDrive/AITrendAnalysis-project/wikipedia_data_with_categories.csv
# Saved batch of 3524 records
# Processing topic: Wikipedia:Categorizing redirects
# Successfully saved 3524 rows to /content/drive/MyDrive/AITrendAnalysis-project/wikipedia_data_with_categories.csv
# Saved batch of 3524 records
# Processing topic: Speaker recognition
# Successfully saved 3524 rows to /content/drive/MyDrive/AITrendAnalysis-project/wikipedia_data_with_categories.csv
# Saved batch of 3524 records
# Processing topic: Environmental damage
# Successfully saved 3524 rows to /content/drive/MyDrive/AITrendAnalysis-project/wikipedia_data_with_categories.csv
# Saved batch of 3524 records
# Processing topic: Computer data storage
# Successfully saved 3524 rows to /content/drive/MyDrive/AITrendAnalysis-project/wikipedia_data_with_categories.csv
# Saved batch of 3524 records
# Processing topic: Leonardo Torres Quevedo
# Successfully saved 3504 rows to /content/drive/MyDrive/AITrendAnalysis-project/wikipedia_data_with_categories.csv
# Saved batch of 3504 records
# Processing topic: Question answering
# Successfully saved 3524 rows to /content/drive/MyDrive/AITrendAnalysis-project/wikipedia_data_with_categories.csv
# Saved batch of 3524 records
# Processing topic: Ann B. Stahl
# Successfully saved 2238 rows to /content/drive/MyDrive/AITrendAnalysis-project/wikipedia_data_with_categories.csv
# Saved batch of 2238 records
# Processing topic: University at Buffalo
# Successfully saved 3524 rows to /content/drive/MyDrive/AITrendAnalysis-project/wikipedia_data_with_categories.csv
# Saved batch of 3524 records
# Processing topic: Search engine indexing
# Successfully saved 3524 rows to /content/drive/MyDrive/AITrendAnalysis-project/wikipedia_data_with_categories.csv
# Saved batch of 3524 records
# Processing topic: Causal AI
# Successfully saved 822 rows to /content/drive/MyDrive/AITrendAnalysis-project/wikipedia_data_with_categories.csv
# Saved batch of 822 records
# Processing topic: Bayesian optimization
# Successfully saved 3524 rows to /content/drive/MyDrive/AITrendAnalysis-project/wikipedia_data_with_categories.csv
# Saved batch of 3524 records
# Processing topic: William James
# Successfully saved 3524 rows to /content/drive/MyDrive/AITrendAnalysis-project/wikipedia_data_with_categories.csv
# Saved batch of 3524 records
# Processing topic: Heat-seeking missile
# Successfully saved 3397 rows to /content/drive/MyDrive/AITrendAnalysis-project/wikipedia_data_with_categories.csv
# Saved batch of 3397 records
# Processing topic: Jay Boekelheide
# Successfully saved 3362 rows to /content/drive/MyDrive/AITrendAnalysis-project/wikipedia_data_with_categories.csv
# Saved batch of 3362 records
# Processing topic: Grammar checker
# Successfully saved 3524 rows to /content/drive/MyDrive/AITrendAnalysis-project/wikipedia_data_with_categories.csv
# Saved batch of 3524 records
# Processing topic: Emergence
# Successfully saved 3524 rows to /content/drive/MyDrive/AITrendAnalysis-project/wikipedia_data_with_categories.csv
# Saved batch of 3524 records
# Processing topic: E!
# Successfully saved 3524 rows to /content/drive/MyDrive/AITrendAnalysis-project/wikipedia_data_with_categories.csv
# Saved batch of 3524 records
# Processing topic: Smart home
# Successfully saved 3524 rows to /content/drive/MyDrive/AITrendAnalysis-project/wikipedia_data_with_categories.csv
# Saved batch of 3524 records
# Processing topic: Alloys
# Successfully saved 3524 rows to /content/drive/MyDrive/AITrendAnalysis-project/wikipedia_data_with_categories.csv
# Saved batch of 3524 records
# Processing topic: Google Code Search
# Successfully saved 3524 rows to /content/drive/MyDrive/AITrendAnalysis-project/wikipedia_data_with_categories.csv
# Saved batch of 3524 records
# Processing topic: Greek-English Lexicon
# Successfully saved 3424 rows to /content/drive/MyDrive/AITrendAnalysis-project/wikipedia_data_with_categories.csv
# Saved batch of 3424 records
# Processing topic: GOOG-411
# Successfully saved 3524 rows to /content/drive/MyDrive/AITrendAnalysis-project/wikipedia_data_with_categories.csv
# Saved batch of 3524 records
# Processing topic: Excitatory postsynaptic potential
# Successfully saved 3524 rows to /content/drive/MyDrive/AITrendAnalysis-project/wikipedia_data_with_categories.csv
# Saved batch of 3524 records
# Processing topic: Anthropogenic climate change
# Successfully saved 3524 rows to /content/drive/MyDrive/AITrendAnalysis-project/wikipedia_data_with_categories.csv
# Saved batch of 3524 records
# Processing topic: Alan Robert Murray
# Successfully saved 3521 rows to /content/drive/MyDrive/AITrendAnalysis-project/wikipedia_data_with_categories.csv
# Saved batch of 3521 records
# Processing topic: Facial recognition system
# ...
# Saved batch of 3524 records
# Processing topic: Citrus production
# Successfully saved 3524 rows to /content/drive/MyDrive/AITrendAnalysis-project/wikipedia_data_with_categories.csv
# Saved batch of 3524 records
# Processing topic: Auction
# Successfully saved 3524 rows to /content/drive/MyDrive/AITrendAnalysis-project/wikipedia_data_with_categories.csv
# Saved batch of 3524 records
# Processing topic: Battlestar Galactica (1978 TV series)
# Successfully saved 3524 rows to /content/drive/MyDrive/AITrendAnalysis-project/wikipedia_data_with_categories.csv
# Saved batch of 3524 records
# Processing topic: Ground expression
# Successfully saved 3524 rows to /content/drive/MyDrive/AITrendAnalysis-project/wikipedia_data_with_categories.csv
# Saved batch of 3524 records
# Processing topic: Mittens (chess engine)
# Successfully saved 758 rows to /content/drive/MyDrive/AITrendAnalysis-project/wikipedia_data_with_categories.csv
# Saved batch of 758 records
# Processing topic: Fine chemical
# Successfully saved 3524 rows to /content/drive/MyDrive/AITrendAnalysis-project/wikipedia_data_with_categories.csv
# Saved batch of 3524 records
# Processing topic: Big memory
# Successfully saved 3337 rows to /content/drive/MyDrive/AITrendAnalysis-project/wikipedia_data_with_categories.csv
# Saved batch of 3337 records
# Processing topic: Thermodynamic
# Successfully saved 3524 rows to /content/drive/MyDrive/AITrendAnalysis-project/wikipedia_data_with_categories.csv
# Saved batch of 3524 records
# Processing topic: Chess piece relative value
# Successfully saved 3524 rows to /content/drive/MyDrive/AITrendAnalysis-project/wikipedia_data_with_categories.csv
# Saved batch of 3524 records
# Processing topic: Andrew Whitehurst
# Successfully saved 3308 rows to /content/drive/MyDrive/AITrendAnalysis-project/wikipedia_data_with_categories.csv
# Saved batch of 3308 records
# Processing topic: MIT Computer Science and Artificial Intelligence Laboratory
# Successfully saved 3524 rows to /content/drive/MyDrive/AITrendAnalysis-project/wikipedia_data_with_categories.csv
# Saved batch of 3524 records
# Processing topic: Applied mathematics
# Successfully saved 3524 rows to /content/drive/MyDrive/AITrendAnalysis-project/wikipedia_data_with_categories.csv
# Saved batch of 3524 records
# Processing topic: Genomics
# Successfully saved 3524 rows to /content/drive/MyDrive/AITrendAnalysis-project/wikipedia_data_with_categories.csv
# Saved batch of 3524 records
# Processing topic: Airplane
# Successfully saved 3524 rows to /content/drive/MyDrive/AITrendAnalysis-project/wikipedia_data_with_categories.csv
# Saved batch of 3524 records
# Processing topic: Forensic engineering
# Successfully saved 3524 rows to /content/drive/MyDrive/AITrendAnalysis-project/wikipedia_data_with_categories.csv
# Saved batch of 3524 records
# Processing topic: Oliver Selfridge
# Successfully saved 3524 rows to /content/drive/MyDrive/AITrendAnalysis-project/wikipedia_data_with_categories.csv
# Saved batch of 3524 records
# Processing topic: King Kong (1976 film)
# Successfully saved 3524 rows to /content/drive/MyDrive/AITrendAnalysis-project/wikipedia_data_with_categories.csv
# Saved batch of 3524 records
# Processing topic: Category:Articles lacking reliable references from August 2014
# Successfully saved 3521 rows to /content/drive/MyDrive/AITrendAnalysis-project/wikipedia_data_with_categories.csv
# Saved batch of 3521 records
# Processing topic: Genetic algorithms
# Successfully saved 3524 rows to /content/drive/MyDrive/AITrendAnalysis-project/wikipedia_data_with_categories.csv
# Saved batch of 3524 records
# Processing topic: Lyndon Johnson
# Successfully saved 3524 rows to /content/drive/MyDrive/AITrendAnalysis-project/wikipedia_data_with_categories.csv
# Saved batch of 3524 records
# Processing topic: Offshore engineering
# Successfully saved 3361 rows to /content/drive/MyDrive/AITrendAnalysis-project/wikipedia_data_with_categories.csv
# Saved batch of 3361 records
# Processing topic: Alex Krizhevsky
# Successfully saved 1674 rows to /content/drive/MyDrive/AITrendAnalysis-project/wikipedia_data_with_categories.csv
# Saved batch of 1674 records
# Processing topic: Full stop
# Successfully saved 3524 rows to /content/drive/MyDrive/AITrendAnalysis-project/wikipedia_data_with_categories.csv
# Saved batch of 3524 records
# Processing topic: Biomolecular target
# Successfully saved 3376 rows to /content/drive/MyDrive/AITrendAnalysis-project/wikipedia_data_with_categories.csv
# Saved batch of 3376 records
# Processing topic: 2001: A Space Odyssey (film)
# Successfully saved 3524 rows to /content/drive/MyDrive/AITrendAnalysis-project/wikipedia_data_with_categories.csv
# Saved batch of 3524 records
# Processing topic: Mechanical Gecko
# Successfully saved 3425 rows to /content/drive/MyDrive/AITrendAnalysis-project/wikipedia_data_with_categories.csv
# Saved batch of 3425 records
# Processing topic: Engineering
# Successfully saved 3524 rows to /content/drive/MyDrive/AITrendAnalysis-project/wikipedia_data_with_categories.csv
# Saved batch of 3524 records
# Processing topic: Association for Computational Linguistics
# Successfully saved 3524 rows to /content/drive/MyDrive/AITrendAnalysis-project/wikipedia_data_with_categories.csv
# Saved batch of 3524 records
# Processing topic: Language interpretation
# Successfully saved 3524 rows to /content/drive/MyDrive/AITrendAnalysis-project/wikipedia_data_with_categories.csv
# Saved batch of 3524 records
# Processing topic: List of professional Go tournaments
# Successfully saved 3524 rows to /content/drive/MyDrive/AITrendAnalysis-project/wikipedia_data_with_categories.csv
# Saved batch of 3524 records
# Processing topic: Arthur E. Bryson
# Successfully saved 3521 rows to /content/drive/MyDrive/AITrendAnalysis-project/wikipedia_data_with_categories.csv
# Saved batch of 3521 records
# Processing topic: Automation in construction
# Successfully saved 1562 rows to /content/drive/MyDrive/AITrendAnalysis-project/wikipedia_data_with_categories.csv
# Saved batch of 1562 records
# Processing topic: General Assembly
# Successfully saved 3523 rows to /content/drive/MyDrive/AITrendAnalysis-project/wikipedia_data_with_categories.csv
# Saved batch of 3523 records
# Processing topic: Insheeption
# Successfully saved 3524 rows to /content/drive/MyDrive/AITrendAnalysis-project/wikipedia_data_with_categories.csv
# Saved batch of 3524 records
# Processing topic: Horizon scanning
# Successfully saved 1459 rows to /content/drive/MyDrive/AITrendAnalysis-project/wikipedia_data_with_categories.csv
# Saved batch of 1459 records
# Processing topic: MultiDimensional eXpressions
# Successfully saved 3524 rows to /content/drive/MyDrive/AITrendAnalysis-project/wikipedia_data_with_categories.csv
# Saved batch of 3524 records
# Processing topic: Google AI
# Successfully saved 1995 rows to /content/drive/MyDrive/AITrendAnalysis-project/wikipedia_data_with_categories.csv
# Saved batch of 1995 records
# Processing topic: AlphaFold 2
# Successfully saved 1507 rows to /content/drive/MyDrive/AITrendAnalysis-project/wikipedia_data_with_categories.csv
# Saved batch of 1507 records
# Processing topic: GNU Chess
# Successfully saved 3524 rows to /content/drive/MyDrive/AITrendAnalysis-project/wikipedia_data_with_categories.csv
# Saved batch of 3524 records
# Processing topic: Category:Articles needing additional references from September 2023
# Successfully saved 549 rows to /content/drive/MyDrive/AITrendAnalysis-project/wikipedia_data_with_categories.csv
# Saved batch of 549 records
# Processing topic: Data center
# Successfully saved 3524 rows to /content/drive/MyDrive/AITrendAnalysis-project/wikipedia_data_with_categories.csv
# Saved batch of 3524 records
# Processing topic: Feature detection (computer vision)
# Successfully saved 3524 rows to /content/drive/MyDrive/AITrendAnalysis-project/wikipedia_data_with_categories.csv
# Saved batch of 3524 records
# Processing topic: U.S. Congress
# Successfully saved 3524 rows to /content/drive/MyDrive/AITrendAnalysis-project/wikipedia_data_with_categories.csv
# Saved batch of 3524 records
# Processing topic: Degenerate dimension
# Successfully saved 3524 rows to /content/drive/MyDrive/AITrendAnalysis-project/wikipedia_data_with_categories.csv
# Saved batch of 3524 records
# Processing topic: Template:Computer science
# Successfully saved 3524 rows to /content/drive/MyDrive/AITrendAnalysis-project/wikipedia_data_with_categories.csv
# Saved batch of 3524 records
# Processing topic: Document-term matrix
# Successfully saved 3524 rows to /content/drive/MyDrive/AITrendAnalysis-project/wikipedia_data_with_categories.csv
# Saved batch of 3524 records
# Processing topic: History of the Internet
# Successfully saved 3524 rows to /content/drive/MyDrive/AITrendAnalysis-project/wikipedia_data_with_categories.csv
# Saved batch of 3524 records
# Processing topic: Machine learning in earth sciences
# Successfully saved 1196 rows to /content/drive/MyDrive/AITrendAnalysis-project/wikipedia_data_with_categories.csv
# Saved batch of 1196 records
# Processing topic: Joint probability distribution
# Successfully saved 3524 rows to /content/drive/MyDrive/AITrendAnalysis-project/wikipedia_data_with_categories.csv
# Saved batch of 3524 records
# Processing topic: ImageNet
# Successfully saved 3170 rows to /content/drive/MyDrive/AITrendAnalysis-project/wikipedia_data_with_categories.csv
# Saved batch of 3170 records
# Processing topic: John P. A. Ioannidis
# Successfully saved 3493 rows to /content/drive/MyDrive/AITrendAnalysis-project/wikipedia_data_with_categories.csv
# Saved batch of 3493 records
# Processing topic: Geotechnical engineering
# Successfully saved 3524 rows to /content/drive/MyDrive/AITrendAnalysis-project/wikipedia_data_with_categories.csv
# Saved batch of 3524 records
# Processing topic: Java Data Mining
# Successfully saved 3520 rows to /content/drive/MyDrive/AITrendAnalysis-project/wikipedia_data_with_categories.csv
# Saved batch of 3520 records
# Processing topic: David Vickery
# Successfully saved 3426 rows to /content/drive/MyDrive/AITrendAnalysis-project/wikipedia_data_with_categories.csv
# Saved batch of 3426 records
# Processing topic: DeepSeek (chatbot)
# Processing topic: Piezoelectricity
# Successfully saved 3542 rows to /content/drive/MyDrive/AITrendAnalysis-project/wikipedia_data_with_categories.csv
# Saved batch of 3542 records
# Processing topic: Albert Borgmann
# Successfully saved 3524 rows to /content/drive/MyDrive/AITrendAnalysis-project/wikipedia_data_with_categories.csv
# Saved batch of 3524 records
# Processing topic: Treebank
# Successfully saved 3524 rows to /content/drive/MyDrive/AITrendAnalysis-project/wikipedia_data_with_categories.csv
# Saved batch of 3524 records
# Processing topic: FrameNet
# Successfully saved 3524 rows to /content/drive/MyDrive/AITrendAnalysis-project/wikipedia_data_with_categories.csv
# Saved batch of 3524 records
# Processing topic: Stanford University
# Successfully saved 3524 rows to /content/drive/MyDrive/AITrendAnalysis-project/wikipedia_data_with_categories.csv
# Saved batch of 3524 records
# Processing topic: Homework (Daft Punk album)
# Successfully saved 3524 rows to /content/drive/MyDrive/AITrendAnalysis-project/wikipedia_data_with_categories.csv
# Saved batch of 3524 records
# Processing topic: Design
# Successfully saved 3524 rows to /content/drive/MyDrive/AITrendAnalysis-project/wikipedia_data_with_categories.csv
# Saved batch of 3524 records
# Processing topic: Engineer's degree
# Successfully saved 3524 rows to /content/drive/MyDrive/AITrendAnalysis-project/wikipedia_data_with_categories.csv
# Saved batch of 3524 records
# Processing topic: Ebola virus
# Successfully saved 3524 rows to /content/drive/MyDrive/AITrendAnalysis-project/wikipedia_data_with_categories.csv
# Saved batch of 3524 records
# Processing topic: Film Quarterly
# Successfully saved 3524 rows to /content/drive/MyDrive/AITrendAnalysis-project/wikipedia_data_with_categories.csv
# Saved batch of 3524 records
# Processing topic: London Review of Books
# Successfully saved 3524 rows to /content/drive/MyDrive/AITrendAnalysis-project/wikipedia_data_with_categories.csv
# Saved batch of 3524 records
# Processing topic: Marc Peter Deisenroth
# Processing topic: Computer scientist
# Successfully saved 3524 rows to /content/drive/MyDrive/AITrendAnalysis-project/wikipedia_data_with_categories.csv
# Saved batch of 3524 records
# Processing topic: Learning to rank
# Successfully saved 3524 rows to /content/drive/MyDrive/AITrendAnalysis-project/wikipedia_data_with_categories.csv
# Saved batch of 3524 records
# Processing topic: Diving cylinder
# Successfully saved 3524 rows to /content/drive/MyDrive/AITrendAnalysis-project/wikipedia_data_with_categories.csv
# Saved batch of 3524 records
# Processing topic: Data reduction
# Successfully saved 3524 rows to /content/drive/MyDrive/AITrendAnalysis-project/wikipedia_data_with_categories.csv
# Saved batch of 3524 records
# Processing topic: Category:Harv and Sfn template errors
# Successfully saved 1799 rows to /content/drive/MyDrive/AITrendAnalysis-project/wikipedia_data_with_categories.csv
# Saved batch of 1799 records
# Processing topic: Diagram
# Successfully saved 3524 rows to /content/drive/MyDrive/AITrendAnalysis-project/wikipedia_data_with_categories.csv
# Saved batch of 3524 records
# Processing topic: Language technology
# Successfully saved 3524 rows to /content/drive/MyDrive/AITrendAnalysis-project/wikipedia_data_with_categories.csv
# Saved batch of 3524 records
# Processing topic: Atanasoff–Berry computer
# Successfully saved 3524 rows to /content/drive/MyDrive/AITrendAnalysis-project/wikipedia_data_with_categories.csv
# Saved batch of 3524 records
# Processing topic: Battery storage
# Successfully saved 3017 rows to /content/drive/MyDrive/AITrendAnalysis-project/wikipedia_data_with_categories.csv
# Saved batch of 3017 records
# Processing topic: Kevin Kelly (editor)
# Successfully saved 3524 rows to /content/drive/MyDrive/AITrendAnalysis-project/wikipedia_data_with_categories.csv
# Saved batch of 3524 records
# Processing topic: Dialect
# Successfully saved 3524 rows to /content/drive/MyDrive/AITrendAnalysis-project/wikipedia_data_with_categories.csv
# Saved batch of 3524 records
# Processing topic: J. Hoberman
# Successfully saved 3524 rows to /content/drive/MyDrive/AITrendAnalysis-project/wikipedia_data_with_categories.csv
# Saved batch of 3524 records
# Processing topic: Electric unicycle
# Successfully saved 2574 rows to /content/drive/MyDrive/AITrendAnalysis-project/wikipedia_data_with_categories.csv
# Saved batch of 2574 records
# Processing topic: John von Neumann
# Successfully saved 3524 rows to /content/drive/MyDrive/AITrendAnalysis-project/wikipedia_data_with_categories.csv
# Saved batch of 3524 records
# Processing topic: Portal:Art
# Successfully saved 3524 rows to /content/drive/MyDrive/AITrendAnalysis-project/wikipedia_data_with_categories.csv
# Saved batch of 3524 records
# Processing topic: Speech processing
# Successfully saved 3524 rows to /content/drive/MyDrive/AITrendAnalysis-project/wikipedia_data_with_categories.csv
# Saved batch of 3524 records
# Processing topic: Animatronics
# Successfully saved 3524 rows to /content/drive/MyDrive/AITrendAnalysis-project/wikipedia_data_with_categories.csv
# Saved batch of 3524 records
# Processing topic: Language
# Successfully saved 3524 rows to /content/drive/MyDrive/AITrendAnalysis-project/wikipedia_data_with_categories.csv
# Saved batch of 3524 records
# Processing topic: Maya civilization
# Successfully saved 3524 rows to /content/drive/MyDrive/AITrendAnalysis-project/wikipedia_data_with_categories.csv
# Saved batch of 3524 records
# Processing topic: Just Can't Get Enough (Black Eyed Peas song)
# Successfully saved 2376 rows to /content/drive/MyDrive/AITrendAnalysis-project/wikipedia_data_with_categories.csv
# Saved batch of 2376 records
# Processing topic: Necrobotics
# Successfully saved 939 rows to /content/drive/MyDrive/AITrendAnalysis-project/wikipedia_data_with_categories.csv
# Saved batch of 939 records
# Processing topic: Regularization (mathematics)
# Successfully saved 3524 rows to /content/drive/MyDrive/AITrendAnalysis-project/wikipedia_data_with_categories.csv
# Saved batch of 3524 records
# Processing topic: Fine-tuning (machine learning)
# Successfully saved 716 rows to /content/drive/MyDrive/AITrendAnalysis-project/wikipedia_data_with_categories.csv
# Saved batch of 716 records
